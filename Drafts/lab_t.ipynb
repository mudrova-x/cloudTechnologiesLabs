// %%
!../../bin/acta lab_t.hpp
// Out:
// line:35
// !Begin(out!sequence_element)
// line:90
// CheckStage(in?sequence_element,out!sequence_element,t:basesim)
// line:190
// End(in?sequence_element)
// Ok

// %% [markdown]
// run the sample

// %%
#pragma cling add_include_path("../../lib/")

const int N = 7; // число звеньев в цепочке проверяющих акторов
#include "lab_t.hpp"

engine eng;
basesim_engine teng;
    
Begin beginStage(eng);
CheckStage stages[N];
End   endStage(eng);
    
beginStage.max_stages_num = 30;
    
sequence_element* last_check_stage = &beginStage.out; // в начальный актор передаем ссылку на первый проверяющий в цепочке
endStage.in(stages[N-1].out); // в финальный актор передаем ссылку на последний проверяющий в цепочке

// каждому актору в цепочке присваиваем ссылку на следующий и вспомогательный идентификатор (для отладки)
for(int i=0; i<N; i++){
    stages[i].engines(eng, teng);  
    
    stages[i].stage_id = i; 
    stages[i].in(*last_check_stage); 
    last_check_stage = &stages[i].out;
}

eng.start();
teng.run();
    
cout << (eng.stopped() ? "Success!!!" : "Failure...");
// Out:
// --- Отправка элемента последовательности из начального актора
// --- CheckStage 0
// ------ Проверка элемента последовательности 2 на этапе № 0
// ------ Сохранение элемента 2 на этапе № 0
// ---------------------------------
// |   НАЙДЕНО ПРОСТОЕ ЧИСЛО: 2   |
// ---------------------------------
// --- Отправка элемента последовательности из начального актора
// --- CheckStage 0
// ------ Проверка элемента последовательности 3 на этапе № 0
// ------ 3 не кратно числу 2
// --- CheckStage 1
// ------ Проверка элемента последовательности 3 на этапе № 1
// ------ Сохранение элемента 3 на этапе № 1
// ---------------------------------
// |   НАЙДЕНО ПРОСТОЕ ЧИСЛО: 3   |
// ---------------------------------
// ------ Возврат к предыдущему актору. stage_id текущего = 0
// --- Отправка элемента последовательности из начального актора
// --- CheckStage 0
// ------ Проверка элемента последовательности 4 на этапе № 0
// ------ 4 кратно числу 2
// --- Отправка элемента последовательности из начального актора
// --- CheckStage 0
// ------ Проверка элемента последовательности 5 на этапе № 0
// ------ 5 не кратно числу 2
// --- CheckStage 1
// ------ Проверка элемента последовательности 5 на этапе № 1
// ------ 5 не кратно числу 3
// --- CheckStage 2
// ------ Проверка элемента последовательности 5 на этапе № 2
// ------ Сохранение элемента 5 на этапе № 2
// ---------------------------------
// |   НАЙДЕНО ПРОСТОЕ ЧИСЛО: 5   |
// ---------------------------------
// ------ Возврат к предыдущему актору. stage_id текущего = 1
// ------ Возврат к предыдущему актору. stage_id текущего = 0
// --- Отправка элемента последовательности из начального актора
// --- CheckStage 0
// ------ Проверка элемента последовательности 6 на этапе № 0
// ------ 6 кратно числу 2
// --- Отправка элемента последовательности из начального актора
// --- CheckStage 0
// ------ Проверка элемента последовательности 7 на этапе № 0
// ------ 7 не кратно числу 2
// --- CheckStage 1
// ------ Проверка элемента последовательности 7 на этапе № 1
// ------ 7 не кратно числу 3
// --- CheckStage 2
// ------ Проверка элемента последовательности 7 на этапе № 2
// ------ 7 не кратно числу 5
// --- CheckStage 3
// ------ Проверка элемента последовательности 7 на этапе № 3
// ------ Сохранение элемента 7 на этапе № 3
// ---------------------------------
// |   НАЙДЕНО ПРОСТОЕ ЧИСЛО: 7   |
// ---------------------------------
// ------ Возврат к предыдущему актору. stage_id текущего = 2
// ------ Возврат к предыдущему актору. stage_id текущего = 1
// ------ Возврат к предыдущему актору. stage_id текущего = 0
// --- Отправка элемента последовательности из начального актора
// --- CheckStage 0
// ------ Проверка элемента последовательности 8 на этапе № 0
// ------ 8 кратно числу 2
// --- Отправка элемента последовательности из начального актора
// --- CheckStage 0
// ------ Проверка элемента последовательности 9 на этапе № 0
// ------ 9 не кратно числу 2
// --- CheckStage 1
// ------ Проверка элемента последовательности 9 на этапе № 1
// ------ 9 кратно числу 3
// ------ Возврат к предыдущему актору. stage_id текущего = 0
// --- Отправка элемента последовательности из начального актора
// --- CheckStage 0
// ------ Проверка элемента последовательности 10 на этапе № 0
// ------ 10 кратно числу 2
// --- Отправка элемента последовательности из начального актора
// --- CheckStage 0
// ------ Проверка элемента последовательности 11 на этапе № 0
// ------ 11 не кратно числу 2
// --- CheckStage 1
// ------ Проверка элемента последовательности 11 на этапе № 1
// ------ 11 не кратно числу 3
// --- CheckStage 2
// ------ Проверка элемента последовательности 11 на этапе № 2
// ------ 11 не кратно числу 5
// --- CheckStage 3
// ------ Проверка элемента последовательности 11 на этапе № 3
// ------ 11 не кратно числу 7
// --- CheckStage 4
// ------ Проверка элемента последовательности 11 на этапе № 4
// ------ Сохранение элемента 11 на этапе № 4
// ---------------------------------
// |   НАЙДЕНО ПРОСТОЕ ЧИСЛО: 11   |
// ---------------------------------
// ------ Возврат к предыдущему актору. stage_id текущего = 3
// ------ Возврат к предыдущему актору. stage_id текущего = 2
// ------ Возврат к предыдущему актору. stage_id текущего = 1
// ------ Возврат к предыдущему актору. stage_id текущего = 0
// --- Отправка элемента последовательности из начального актора
// --- CheckStage 0
// ------ Проверка элемента последовательности 12 на этапе № 0
// ------ 12 кратно числу 2
// --- Отправка элемента последовательности из начального актора
// --- CheckStage 0
// ------ Проверка элемента последовательности 13 на этапе № 0
// ------ 13 не кратно числу 2
// --- CheckStage 1
// ------ Проверка элемента последовательности 13 на этапе № 1
// ------ 13 не кратно числу 3
// --- CheckStage 2
// ------ Проверка элемента последовательности 13 на этапе № 2
// ------ 13 не кратно числу 5
// --- CheckStage 3
// ------ Проверка элемента последовательности 13 на этапе № 3
// ------ 13 не кратно числу 7
// --- CheckStage 4
// ------ Проверка элемента последовательности 13 на этапе № 4
// ------ 13 не кратно числу 11
// --- CheckStage 5
// ------ Проверка элемента последовательности 13 на этапе № 5
// ------ Сохранение элемента 13 на этапе № 5
// ---------------------------------
// |   НАЙДЕНО ПРОСТОЕ ЧИСЛО: 13   |
// ---------------------------------
// ------ Возврат к предыдущему актору. stage_id текущего = 4
// ------ Возврат к предыдущему актору. stage_id текущего = 3
// ------ Возврат к предыдущему актору. stage_id текущего = 2
// ------ Возврат к предыдущему актору. stage_id текущего = 1
// ------ Возврат к предыдущему актору. stage_id текущего = 0
// --- Отправка элемента последовательности из начального актора
// --- CheckStage 0
// ------ Проверка элемента последовательности 14 на этапе № 0
// ------ 14 кратно числу 2
// --- Отправка элемента последовательности из начального актора
// --- CheckStage 0
// ------ Проверка элемента последовательности 15 на этапе № 0
// ------ 15 не кратно числу 2
// --- CheckStage 1
// ------ Проверка элемента последовательности 15 на этапе № 1
// ------ 15 кратно числу 3
// ------ Возврат к предыдущему актору. stage_id текущего = 0
// --- Отправка элемента последовательности из начального актора
// --- CheckStage 0
// ------ Проверка элемента последовательности 16 на этапе № 0
// ------ 16 кратно числу 2
// --- Отправка элемента последовательности из начального актора
// --- CheckStage 0
// ------ Проверка элемента последовательности 17 на этапе № 0
// ------ 17 не кратно числу 2
// --- CheckStage 1
// ------ Проверка элемента последовательности 17 на этапе № 1
// ------ 17 не кратно числу 3
// --- CheckStage 2
// ------ Проверка элемента последовательности 17 на этапе № 2
// ------ 17 не кратно числу 5
// --- CheckStage 3
// ------ Проверка элемента последовательности 17 на этапе № 3
// ------ 17 не кратно числу 7
// --- CheckStage 4
// ------ Проверка элемента последовательности 17 на этапе № 4
// ------ 17 не кратно числу 11
// --- CheckStage 5
// ------ Проверка элемента последовательности 17 на этапе № 5
// ------ 17 не кратно числу 13
// --- CheckStage 6
// ------ Проверка элемента последовательности 17 на этапе № 6
// ------ Сохранение элемента 17 на этапе № 6
// ---------------------------------
// |   НАЙДЕНО ПРОСТОЕ ЧИСЛО: 17   |
// ---------------------------------
// ------ Возврат к предыдущему актору. stage_id текущего = 5
// ------ Возврат к предыдущему актору. stage_id текущего = 4
// ------ Возврат к предыдущему актору. stage_id текущего = 3
// ------ Возврат к предыдущему актору. stage_id текущего = 2
// ------ Возврат к предыдущему актору. stage_id текущего = 1
// ------ Возврат к предыдущему актору. stage_id текущего = 0
// --- Отправка элемента последовательности из начального актора
// --- CheckStage 0
// ------ Проверка элемента последовательности 18 на этапе № 0
// ------ 18 кратно числу 2
// --- Отправка элемента последовательности из начального актора
// --- CheckStage 0
// ------ Проверка элемента последовательности 19 на этапе № 0
// ------ 19 не кратно числу 2
// --- CheckStage 1
// ------ Проверка элемента последовательности 19 на этапе № 1
// ------ 19 не кратно числу 3
// --- CheckStage 2
// ------ Проверка элемента последовательности 19 на этапе № 2
// ------ 19 не кратно числу 5
// --- CheckStage 3
// ------ Проверка элемента последовательности 19 на этапе № 3
// ------ 19 не кратно числу 7
// --- CheckStage 4
// ------ Проверка элемента последовательности 19 на этапе № 4
// ------ 19 не кратно числу 11
// --- CheckStage 5
// ------ Проверка элемента последовательности 19 на этапе № 5
// ------ 19 не кратно числу 13
// --- CheckStage 6
// ------ Проверка элемента последовательности 19 на этапе № 6
// ------ 19 не кратно числу 17
// --- Сохранение последнего элемента 19
// ---------------------------------
// |   ПОСЛЕДНЕЕ ПРОСТОЕ ЧИСЛО: 19   |
// ---------------------------------
// Success!!!

// %%
#pragma cling add_include_path("../../lib/")

const  int N = 4;
#include "lab_t.hpp"

engine eng;
basesim_engine teng;
    
Begin b(eng, teng);
Stage s[N];
End   e(eng);
    
b.max_num = 20;
    
validation* last_out = &b.out;
e.in(s[N-1].out);
    
for(int i=0; i<N; i++){
    s[i].engines(eng);  
    
    s[i].in(*last_out); 
    last_out = &s[i].out;
}

eng.start();
teng.run();
    
cout << (eng.stopped() ? "Success!!!" : "Failure...");
// Out:
// input_line_9:5:7: error: no matching constructor for initialization of 'Begin'
// Begin b(eng, teng);
//       ^ ~~~~~~~~~
// ./lab_t.hpp:41:2: note: candidate constructor not viable: requires single argument 'e', but 2 arguments were provided
//         Begin(templet::engine&e) :Begin() {
//         ^
// ./lab_t.hpp:37:8: note: candidate constructor (the implicit copy constructor) not viable: requires 1 argument, but 2 were provided
// struct Begin :public templet::actor {
//        ^
// ./lab_t.hpp:37:8: note: candidate constructor (the implicit move constructor) not viable: requires 1 argument, but 2 were provided
// ./lab_t.hpp:45:2: note: candidate constructor not viable: requires 0 arguments, but 2 were provided
//         Begin() :templet::actor(true),
//         ^
// input_line_9:6:1: error: unknown type name 'Stage'
// Stage s[N];
// ^
// input_line_9:11:1: error: unknown type name 'validation'
// validation* last_out = &b.out;
// ^
// Interpreter Error:
// ERROR: received unknown message
// Message type: usage_request
// ERROR: received unknown message
// Message type: usage_request

// %%
!g++ lab_t.cpp -I ../../lib -o lab_t
// Out:
// In file included from lab_t.cpp:1:
// lab_t.hpp:33:51: error: expected class-name before ‘{’ token
//    33 | class multiplicitycheck : public templet::basesim {
//       |                                                   ^
// lab_t.hpp: In member function ‘void Begin::on_out(validation&)’:
// lab_t.hpp:75:17: error: no matching function for call to ‘templet::basesim_task::submit(int)’
//    75 |         t.submit(1);
//       |         ~~~~~~~~^~~
// In file included from lab_t.hpp:22,
//                  from lab_t.cpp:1:
// ../../lib/basesim.hpp:84:22: note: candidate: ‘void templet::basesim_task::submit()’
//    84 |                 void submit() { _actor->suspend(); _eng->submit(*this); }
//       |                      ^~~~~~
// ../../lib/basesim.hpp:84:22: note:   candidate expects 0 arguments, 1 provided
// lab_t.cpp: In function ‘int main()’:
// lab_t.cpp:9:13: error: ‘N’ was not declared in this scope
//     9 |     Stage s[N];
//       |             ^
// lab_t.cpp:15:10: error: ‘s’ was not declared in this scope
//    15 |     e.in(s[N-1].out);
//       |          ^

// %%
!./lab
// Out:
// --- Begin on_out
// 2
// num == 0
// ------------------------ Найдено простое число: 2
// --- Begin on_out
// 3
// В сообщении: 3 В акторе: 2
// 3 не кратно числу 2
// num == 0
// ------------------------ Найдено простое число: 3
// В сообщении: 0 В акторе: 2
// Возвращаемся 0
// --- Begin on_out
// 4
// В сообщении: 4 В акторе: 2
// Кратно. Возвращаемся 2
// --- Begin on_out
// 5
// В сообщении: 5 В акторе: 2
// 5 не кратно числу 2
// В сообщении: 5 В акторе: 3
// 5 не кратно числу 3
// num == 0
// ------------------------ Найдено простое число: 5
// В сообщении: 0 В акторе: 3
// Возвращаемся 0
// В сообщении: 0 В акторе: 2
// Возвращаемся 0
// --- Begin on_out
// 6
// В сообщении: 6 В акторе: 2
// Кратно. Возвращаемся 2
// --- Begin on_out
// 7
// В сообщении: 7 В акторе: 2
// 7 не кратно числу 2
// В сообщении: 7 В акторе: 3
// 7 не кратно числу 3
// В сообщении: 7 В акторе: 5
// 7 не кратно числу 5
// num == 0
// ------------------------ Найдено простое число: 7
// В сообщении: 0 В акторе: 5
// Возвращаемся 0
// В сообщении: 0 В акторе: 3
// Возвращаемся 0
// В сообщении: 0 В акторе: 2
// Возвращаемся 0
// --- Begin on_out
// 8
// В сообщении: 8 В акторе: 2
// Кратно. Возвращаемся 2
// --- Begin on_out
// 9
// В сообщении: 9 В акторе: 2
// 9 не кратно числу 2
// В сообщении: 9 В акторе: 3
// Кратно. Возвращаемся 3
// В сообщении: 0 В акторе: 2
// Возвращаемся 0
// --- Begin on_out
// 10
// В сообщении: 10 В акторе: 2
// Кратно. Возвращаемся 2
// --- Begin on_out
// 11
// В сообщении: 11 В акторе: 2
// 11 не кратно числу 2
// В сообщении: 11 В акторе: 3
// 11 не кратно числу 3
// В сообщении: 11 В акторе: 5
// 11 не кратно числу 5
// В сообщении: 11 В акторе: 7
// 11 не кратно числу 7
// ------------------------ Последнее простое число в ряду: 11
// Success!!!
// ERROR: received unknown message
// Message type: usage_request
