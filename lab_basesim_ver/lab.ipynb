// %% [markdown]
// ![scheme.drawio.png](attachment:af2ba96a-31a3-4683-a84c-775be80d8632.png)

// %% [markdown]
// ![image.png](attachment:6ebc70f5-c25d-4e4a-9641-3a2c2a2ab9c8.png)

// %% [markdown]
// Спросить:
// - правильно ли поняли, что основное отличие между сообщениями типа "!" и "?" заключается в привязке к конкретному актору?
//   Т.е. !-сообщение привязывается к актору, и можно проверить доступ через access, ? - нужно привязывать вручную через bind + для него сразу генерируется обработчик.
// - Про метод out в рамках цепочки: on_out вызывается в момент, когда следующий актор вызывает _in.send() ?

// %%
!../../bin/acta lab.hpp
// Out:
// line:35
// !Begin(out!sequence_element)
// line:91
// CheckStage(in?sequence_element,out!sequence_element,t:basesim)
// line:191
// End(in?sequence_element)
// Ok

// %% [markdown]
// run the sample

// %%
#pragma cling add_include_path("../../lib/")

const int N = 5; // число звеньев в цепочке проверяющих акторов (не считая конечное звено - актор end)
// => всего найденных чисел будет N+1

#include "lab.hpp"

engine eng;
basesim_engine teng;
    
Begin beginStage(eng);
CheckStage stages[N];
End   endStage(eng);
    
beginStage.max_elements_num = 30;
    
sequence_element* last_check_stage = &beginStage.out; // в начальный актор передаем ссылку на собщение первого проверяющего актора в цепочке
endStage.in(stages[N-1].out); // в финальный актор передаем ссылку на собщение последнего проверяющего в цепочке
        
// каждому актору в цепочке присваиваем ссылку на сообщение следующего и вспомогательный идентификатор (для отладки)
for(int i=0; i<N; i++){
    stages[i].engines(eng, teng);  
    
    stages[i].stage_id = i; 
    stages[i].in(*last_check_stage); 
    last_check_stage = &stages[i].out;
}

eng.start();
teng.run();
    
cout << (eng.stopped() ? "Успешное выполнение" : "Возникла ошибка");

if (eng.stopped())
{
    std::cout << "\nMaximum number of tasks executed in parallel : " << teng.Pmax() << std::endl;
    std::cout << "Time of sequential execution of all tasks    : " << teng.T1() << std::endl;
    std::cout << "Time of parallel   execution of all tasks    : " << teng.Tp() << std::endl;
}
// Out:
// --- Отправка элемента последовательности 2 из начального актора Begin
// --- CheckStage 0
// ------ Проверка элемента последовательности 2 в акторе со stage_id = 0
// ------ Сохранение элемента 2 в акторе со stage_id = 0
// ---------------------------------
// |   НАЙДЕНО ПРОСТОЕ ЧИСЛО: 2   |
// ---------------------------------
// --- Отправка элемента последовательности 3 из начального актора Begin
// --- CheckStage 0
// ------ Проверка элемента последовательности 3 в акторе со stage_id = 0
// ------ 3 не кратно числу 2
// --- Отправка элемента последовательности 4 из начального актора Begin
// --- CheckStage 1
// ------ Проверка элемента последовательности 3 в акторе со stage_id = 1
// ------ Сохранение элемента 3 в акторе со stage_id = 1
// ---------------------------------
// |   НАЙДЕНО ПРОСТОЕ ЧИСЛО: 3   |
// ---------------------------------
// --- CheckStage 0
// ------ Проверка элемента последовательности 4 в акторе со stage_id = 0
// ------ 4 кратно числу 2
// --- Отправка элемента последовательности 5 из начального актора Begin
// --- CheckStage 0
// ------ Проверка элемента последовательности 5 в акторе со stage_id = 0
// ------ 5 не кратно числу 2
// --- Отправка элемента последовательности 6 из начального актора Begin
// --- CheckStage 1
// ------ Проверка элемента последовательности 5 в акторе со stage_id = 1
// --- CheckStage 0
// ------ 5 не кратно числу 3
// ------ Проверка элемента последовательности 6 в акторе со stage_id = 0
// --- CheckStage 2
// ------ Проверка элемента последовательности 5 в акторе со stage_id = 2
// ------ Сохранение элемента 5 в акторе со stage_id = 2
// ---------------------------------
// |   НАЙДЕНО ПРОСТОЕ ЧИСЛО: 5   |
// ---------------------------------
// ------ 6 кратно числу 2
// --- Отправка элемента последовательности 7 из начального актора Begin
// --- CheckStage 0
// ------ Проверка элемента последовательности 7 в акторе со stage_id = 0
// ------ 7 не кратно числу 2
// --- Отправка элемента последовательности 8 из начального актора Begin
// --- CheckStage 1
// ------ Проверка элемента последовательности 7 в акторе со stage_id = 1
// --- CheckStage 0
// ------ 7 не кратно числу 3
// ------ Проверка элемента последовательности 8 в акторе со stage_id = 0
// --- CheckStage 2
// ------ Проверка элемента последовательности 7 в акторе со stage_id = 2
// ------ 8 кратно числу 2
// ------ 7 не кратно числу 5
// --- Отправка элемента последовательности 9 из начального актора Begin
// --- CheckStage 0
// ------ Проверка элемента последовательности 9 в акторе со stage_id = 0
// --- CheckStage 3
// ------ Проверка элемента последовательности 7 в акторе со stage_id = 3
// ------ Сохранение элемента 7 в акторе со stage_id = 3
// ---------------------------------
// |   НАЙДЕНО ПРОСТОЕ ЧИСЛО: 7   |
// ---------------------------------
// ------ 9 не кратно числу 2
// --- Отправка элемента последовательности 10 из начального актора Begin
// --- CheckStage 1
// ------ Проверка элемента последовательности 9 в акторе со stage_id = 1
// --- CheckStage 0
// ------ 9 кратно числу 3
// ------ Проверка элемента последовательности 10 в акторе со stage_id = 0
// ------ 10 кратно числу 2
// --- Отправка элемента последовательности 11 из начального актора Begin
// --- CheckStage 0
// ------ Проверка элемента последовательности 11 в акторе со stage_id = 0
// ------ 11 не кратно числу 2
// --- Отправка элемента последовательности 12 из начального актора Begin
// --- CheckStage 1
// ------ Проверка элемента последовательности 11 в акторе со stage_id = 1
// --- CheckStage 0
// ------ 11 не кратно числу 3
// ------ Проверка элемента последовательности 12 в акторе со stage_id = 0
// --- CheckStage 2
// ------ Проверка элемента последовательности 11 в акторе со stage_id = 2
// ------ 12 кратно числу 2
// ------ 11 не кратно числу 5
// --- Отправка элемента последовательности 13 из начального актора Begin
// --- CheckStage 0
// ------ Проверка элемента последовательности 13 в акторе со stage_id = 0
// --- CheckStage 3
// ------ Проверка элемента последовательности 11 в акторе со stage_id = 3
// ------ 13 не кратно числу 2
// ------ 11 не кратно числу 7
// --- Отправка элемента последовательности 14 из начального актора Begin
// --- CheckStage 1
// ------ Проверка элемента последовательности 13 в акторе со stage_id = 1
// --- CheckStage 0
// --- CheckStage 4
// ------ Проверка элемента последовательности 11 в акторе со stage_id = 4
// ------ Сохранение элемента 11 в акторе со stage_id = 4
// ---------------------------------
// |   НАЙДЕНО ПРОСТОЕ ЧИСЛО: 11   |
// ---------------------------------
// ------ 13 не кратно числу 3
// ------ Проверка элемента последовательности 14 в акторе со stage_id = 0
// --- CheckStage 2
// ------ Проверка элемента последовательности 13 в акторе со stage_id = 2
// ------ 14 кратно числу 2
// ------ 13 не кратно числу 5
// --- Отправка элемента последовательности 15 из начального актора Begin
// --- CheckStage 0
// ------ Проверка элемента последовательности 15 в акторе со stage_id = 0
// --- CheckStage 3
// ------ Проверка элемента последовательности 13 в акторе со stage_id = 3
// ------ 15 не кратно числу 2
// ------ 13 не кратно числу 7
// --- Отправка элемента последовательности 16 из начального актора Begin
// --- CheckStage 1
// ------ Проверка элемента последовательности 15 в акторе со stage_id = 1
// --- CheckStage 0
// --- CheckStage 4
// ------ Проверка элемента последовательности 13 в акторе со stage_id = 4
// ------ 15 кратно числу 3
// ------ 13 не кратно числу 11
// ------ Проверка элемента последовательности 16 в акторе со stage_id = 0
// --- Сохранение последнего элемента в акторе End13
// ---------------------------------
// |   ПОСЛЕДНЕЕ ПРОСТОЕ ЧИСЛО: 13   |
// ---------------------------------
// ------ 16 кратно числу 2
// Успешное выполнение
// Maximum number of tasks executed in parallel : 2
// Time of sequential execution of all tasks    : 26000
// Time of parallel   execution of all tasks    : 20000

// %%
!g++ lab.cpp -I ../../lib -o lab

// %%
!./lab
// Out:
// --- Отправка элемента последовательности 2 из начального актора Begin
// --- CheckStage 0
// ------ Проверка элемента последовательности 2 в акторе со stage_id = 0
// ------ Сохранение элемента 2 в акторе со stage_id = 0
// ---------------------------------
// |   НАЙДЕНО ПРОСТОЕ ЧИСЛО: 2   |
// ---------------------------------
// --- Отправка элемента последовательности 3 из начального актора Begin
// --- CheckStage 0
// ------ Проверка элемента последовательности 3 в акторе со stage_id = 0
// ------ 3 не кратно числу 2
// --- Отправка элемента последовательности 4 из начального актора Begin
// --- CheckStage 1
// ------ Проверка элемента последовательности 3 в акторе со stage_id = 1
// ------ Сохранение элемента 3 в акторе со stage_id = 1
// ---------------------------------
// |   НАЙДЕНО ПРОСТОЕ ЧИСЛО: 3   |
// ---------------------------------
// --- CheckStage 0
// ------ Проверка элемента последовательности 4 в акторе со stage_id = 0
// ------ 4 кратно числу 2
// --- Отправка элемента последовательности 5 из начального актора Begin
// --- CheckStage 0
// ------ Проверка элемента последовательности 5 в акторе со stage_id = 0
// ------ 5 не кратно числу 2
// --- Отправка элемента последовательности 6 из начального актора Begin
// --- CheckStage 1
// ------ Проверка элемента последовательности 5 в акторе со stage_id = 1
// --- CheckStage 0
// ------ 5 не кратно числу 3
// ------ Проверка элемента последовательности 6 в акторе со stage_id = 0
// --- CheckStage 2
// ------ Проверка элемента последовательности 5 в акторе со stage_id = 2
// ------ Сохранение элемента 5 в акторе со stage_id = 2
// ---------------------------------
// |   НАЙДЕНО ПРОСТОЕ ЧИСЛО: 5   |
// ---------------------------------
// ------ 6 кратно числу 2
// --- Отправка элемента последовательности 7 из начального актора Begin
// --- CheckStage 0
// ------ Проверка элемента последовательности 7 в акторе со stage_id = 0
// ------ 7 не кратно числу 2
// --- Отправка элемента последовательности 8 из начального актора Begin
// --- CheckStage 1
// ------ Проверка элемента последовательности 7 в акторе со stage_id = 1
// --- CheckStage 0
// ------ 7 не кратно числу 3
// ------ Проверка элемента последовательности 8 в акторе со stage_id = 0
// --- CheckStage 2
// ------ Проверка элемента последовательности 7 в акторе со stage_id = 2
// ------ 8 кратно числу 2
// ------ 7 не кратно числу 5
// --- Отправка элемента последовательности 9 из начального актора Begin
// --- CheckStage 0
// ------ Проверка элемента последовательности 9 в акторе со stage_id = 0
// --- CheckStage 3
// ------ Проверка элемента последовательности 7 в акторе со stage_id = 3
// ------ Сохранение элемента 7 в акторе со stage_id = 3
// ---------------------------------
// |   НАЙДЕНО ПРОСТОЕ ЧИСЛО: 7   |
// ---------------------------------
// ------ 9 не кратно числу 2
// --- Отправка элемента последовательности 10 из начального актора Begin
// --- CheckStage 1
// ------ Проверка элемента последовательности 9 в акторе со stage_id = 1
// --- CheckStage 0
// ------ 9 кратно числу 3
// ------ Проверка элемента последовательности 10 в акторе со stage_id = 0
// ------ 10 кратно числу 2
// --- Отправка элемента последовательности 11 из начального актора Begin
// --- CheckStage 0
// ------ Проверка элемента последовательности 11 в акторе со stage_id = 0
// ------ 11 не кратно числу 2
// --- Отправка элемента последовательности 12 из начального актора Begin
// --- CheckStage 1
// ------ Проверка элемента последовательности 11 в акторе со stage_id = 1
// --- CheckStage 0
// ------ 11 не кратно числу 3
// ------ Проверка элемента последовательности 12 в акторе со stage_id = 0
// --- CheckStage 2
// ------ Проверка элемента последовательности 11 в акторе со stage_id = 2
// ------ 12 кратно числу 2
// ------ 11 не кратно числу 5
// --- Отправка элемента последовательности 13 из начального актора Begin
// --- CheckStage 0
// ------ Проверка элемента последовательности 13 в акторе со stage_id = 0
// --- CheckStage 3
// ------ Проверка элемента последовательности 11 в акторе со stage_id = 3
// ------ 13 не кратно числу 2
// ------ 11 не кратно числу 7
// --- Отправка элемента последовательности 14 из начального актора Begin
// --- CheckStage 1
// ------ Проверка элемента последовательности 13 в акторе со stage_id = 1
// --- CheckStage 0
// --- Сохранение последнего элемента в акторе End11
// ---------------------------------
// |   ПОСЛЕДНЕЕ ПРОСТОЕ ЧИСЛО: 11   |
// ---------------------------------
// ------ 13 не кратно числу 3
// Успешное выполнение
// Maximum number of tasks executed in parallel : 2
// Time of sequential execution of all tasks    : 19000
// Time of parallel   execution of all tasks    : 16000
// ERROR: received unknown message
// Message type: usage_request
// ERROR: received unknown message
// Message type: usage_request
